# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
total_publishing_duration = 60

# %%
# Open the JSON file
with open('base_data/dash_frag100res1080fps30bit6gop2loss8delay0bw100.json', 'r') as file:
    json_data_data_0 = json.load(file)

# Convert JSON data to DataFrame
df_data_0 = pd.DataFrame(json_data_data_0)

# Filter for timestamps between 15 and 75 seconds
df_data_0 = df_data_0[(df_data_0['second'] >= 35) & (df_data_0['second'] <= 95)]

# Reset the metrics to start from 0
df_data_0['second'] -= df_data_0['second'].iloc[0]
df_data_0['totalFrames'] -= df_data_0['totalFrames'].iloc[0]
df_data_0['renderedFrames'] -= df_data_0['renderedFrames'].iloc[0]
df_data_0['droppedFrames'] -= df_data_0['droppedFrames'].iloc[0]
df_data_0['stallDuration'] -= df_data_0['stallDuration'].iloc[0]
df_data_0['stallEvents'] -= df_data_0['stallEvents'].iloc[0]
df_data_0.reset_index(drop=True, inplace=True)

# Convert seconds to milliseconds
df_data_0['behindLive'] *= 1000
df_data_0['buffer'] *= 1000
df_data_0['totalLatency'] *= 1000
df_data_0['stallDuration'] *= 1000

# Percentage of rendered frames
num_frames_total_data_0 = df_data_0['totalFrames'].iloc[-1]
num_frames_rendered_data_0 = df_data_0['renderedFrames'].iloc[-1]
num_frames_dropped_data_0 = df_data_0['droppedFrames'].iloc[-1]
percentage_of_rendered_frames_data_0 = round(num_frames_rendered_data_0 / num_frames_total_data_0 * 100, 2)

# Stalled frames 
num_of_stall_events_data_0 = df_data_0['stallEvents'].iloc[-1]
total_stall_duration_data_0 = df_data_0['stallDuration'].iloc[-1]

# Latencies
avg_behindLive_data_0 = df_data_0['behindLive'].mean()
max_behindLive_data_0 = df_data_0['behindLive'].max()
min_behindLive_data_0 = df_data_0['behindLive'].min()
avg_buffer_data_0 = df_data_0['buffer'].mean()
max_buffer_data_0 = df_data_0['buffer'].max()
min_buffer_data_0 = df_data_0['buffer'].min()
avg_total_time_data_0 = df_data_0['totalLatency'].mean()
max_total_time_data_0 = df_data_0['totalLatency'].max()
min_total_time_data_0 = df_data_0['totalLatency'].min()
total_time_percentiles_data_0 = df_data_0['totalLatency'].quantile([0.25, 0.5, 0.75])
total_time_std_dev_data_0 = df_data_0['totalLatency'].std()

# Bitrate 
bitrate_data_0 = df_data_0['bitrate'].mean() / 1000

# FPS
frame_rate_data_0 = df_data_0['frameRate'].mean()

# %%
# Open the JSON file
with open('base_data/dash_frag100res1080fps30bit6gop2loss8delay0bw100 (1).json', 'r') as file:
    json_data_data_1 = json.load(file)

# Convert JSON data to DataFrame
df_data_1 = pd.DataFrame(json_data_data_1)

# Filter for timestamps between 15 and 75 seconds
df_data_1 = df_data_1[(df_data_1['second'] >= 35) & (df_data_1['second'] <= 95)]

# Reset the metrics to start from 0
df_data_1['second'] -= df_data_1['second'].iloc[0]
df_data_1['totalFrames'] -= df_data_1['totalFrames'].iloc[0]
df_data_1['renderedFrames'] -= df_data_1['renderedFrames'].iloc[0]
df_data_1['droppedFrames'] -= df_data_1['droppedFrames'].iloc[0]
df_data_1['stallDuration'] -= df_data_1['stallDuration'].iloc[0]
df_data_1['stallEvents'] -= df_data_1['stallEvents'].iloc[0]
df_data_1.reset_index(drop=True, inplace=True)

# Convert seconds to milliseconds
df_data_1['behindLive'] *= 1000
df_data_1['buffer'] *= 1000
df_data_1['totalLatency'] *= 1000
df_data_1['stallDuration'] *= 1000

# Percentage of rendered frames
num_frames_total_data_1 = df_data_1['totalFrames'].iloc[-1]
num_frames_rendered_data_1 = df_data_1['renderedFrames'].iloc[-1]
num_frames_dropped_data_1 = df_data_1['droppedFrames'].iloc[-1]
percentage_of_rendered_frames_data_1 = round(num_frames_rendered_data_1 / num_frames_total_data_1 * 100, 2)

# Stalled frames 
num_of_stall_events_data_1 = df_data_1['stallEvents'].iloc[-1]
total_stall_duration_data_1 = df_data_1['stallDuration'].iloc[-1]

# Latencies
avg_behindLive_data_1 = df_data_1['behindLive'].mean()
max_behindLive_data_1 = df_data_1['behindLive'].max()
min_behindLive_data_1 = df_data_1['behindLive'].min()
avg_buffer_data_1 = df_data_1['buffer'].mean()
max_buffer_data_1 = df_data_1['buffer'].max()
min_buffer_data_1 = df_data_1['buffer'].min()
avg_total_time_data_1 = df_data_1['totalLatency'].mean()
max_total_time_data_1 = df_data_1['totalLatency'].max()
min_total_time_data_1 = df_data_1['totalLatency'].min()
total_time_percentiles_data_1 = df_data_1['totalLatency'].quantile([0.25, 0.5, 0.75])
total_time_std_dev_data_1 = df_data_1['totalLatency'].std()

# Bitrate 
bitrate_data_1 = df_data_1['bitrate'].mean() / 1000

# FPS
frame_rate_data_1 = df_data_1['frameRate'].mean()

# %%
# Open the JSON file
with open('base_data/dash_frag100res1080fps30bit6gop2loss8delay0bw100 (2).json', 'r') as file:
    json_data_data_2 = json.load(file)

# Convert JSON data to DataFrame
df_data_2 = pd.DataFrame(json_data_data_2)

# Filter for timestamps between 15 and 75 seconds
df_data_2 = df_data_2[(df_data_2['second'] >= 35) & (df_data_2['second'] <= 95)]

# Reset the metrics to start from 0
df_data_2['second'] -= df_data_2['second'].iloc[0]
df_data_2['totalFrames'] -= df_data_2['totalFrames'].iloc[0]
df_data_2['renderedFrames'] -= df_data_2['renderedFrames'].iloc[0]
df_data_2['droppedFrames'] -= df_data_2['droppedFrames'].iloc[0]
df_data_2['stallDuration'] -= df_data_2['stallDuration'].iloc[0]
df_data_2['stallEvents'] -= df_data_2['stallEvents'].iloc[0]
df_data_2.reset_index(drop=True, inplace=True)

# Convert seconds to milliseconds
df_data_2['behindLive'] *= 1000
df_data_2['buffer'] *= 1000
df_data_2['totalLatency'] *= 1000
df_data_2['stallDuration'] *= 1000

# Percentage of rendered frames
num_frames_total_data_2 = df_data_2['totalFrames'].iloc[-1]
num_frames_rendered_data_2 = df_data_2['renderedFrames'].iloc[-1]
num_frames_dropped_data_2 = df_data_2['droppedFrames'].iloc[-1]
percentage_of_rendered_frames_data_2 = round(num_frames_rendered_data_2 / num_frames_total_data_2 * 100, 2)

# Stalled frames 
num_of_stall_events_data_2 = df_data_2['stallEvents'].iloc[-1]
total_stall_duration_data_2 = df_data_2['stallDuration'].iloc[-1]

# Latencies
avg_behindLive_data_2 = df_data_2['behindLive'].mean()
max_behindLive_data_2 = df_data_2['behindLive'].max()
min_behindLive_data_2 = df_data_2['behindLive'].min()
avg_buffer_data_2 = df_data_2['buffer'].mean()
max_buffer_data_2 = df_data_2['buffer'].max()
min_buffer_data_2 = df_data_2['buffer'].min()
avg_total_time_data_2 = df_data_2['totalLatency'].mean()
max_total_time_data_2 = df_data_2['totalLatency'].max()
min_total_time_data_2 = df_data_2['totalLatency'].min()
total_time_percentiles_data_2 = df_data_2['totalLatency'].quantile([0.25, 0.5, 0.75])
total_time_std_dev_data_2 = df_data_2['totalLatency'].std()

# Bitrate 
bitrate_data_2 = df_data_2['bitrate'].mean() / 1000

# FPS
frame_rate_data_2 = df_data_2['frameRate'].mean()

# %%
# Averages
avg_total_frames = (num_frames_total_data_0 + num_frames_total_data_1 + num_frames_total_data_2) / 3
avg_rendered_frames = (num_frames_rendered_data_0 + num_frames_rendered_data_1 + num_frames_rendered_data_2) / 3
avg_dropped_frames = (num_frames_dropped_data_0 + num_frames_dropped_data_1 + num_frames_dropped_data_2) / 3
avg_percentage_rendered_frames = (percentage_of_rendered_frames_data_0 + percentage_of_rendered_frames_data_1 + percentage_of_rendered_frames_data_2) / 3
avg_num_of_stall_events = (num_of_stall_events_data_0 + num_of_stall_events_data_1 + num_of_stall_events_data_2) / 3
avg_total_stall_duration = (total_stall_duration_data_0 + total_stall_duration_data_1 + total_stall_duration_data_2) / 3
avg_behindLive = (avg_behindLive_data_0 + avg_behindLive_data_1 + avg_behindLive_data_2) / 3
avg_buffer = (avg_buffer_data_0 + avg_buffer_data_1 + avg_buffer_data_2) / 3
avg_total_time = (avg_total_time_data_0 + avg_total_time_data_1 + avg_total_time_data_2) / 3
avg_25th_percentile = (total_time_percentiles_data_0[0.25] + total_time_percentiles_data_1[0.25] + total_time_percentiles_data_2[0.25]) / 3
avg_50th_percentile = (total_time_percentiles_data_0[0.5] + total_time_percentiles_data_1[0.5] + total_time_percentiles_data_2[0.5]) / 3
avg_75th_percentile = (total_time_percentiles_data_0[0.75] + total_time_percentiles_data_1[0.75] + total_time_percentiles_data_2[0.75]) / 3
avg_total_time_std_dev = (total_time_std_dev_data_0 + total_time_std_dev_data_1 + total_time_std_dev_data_2) / 3
avg_bitrate = (bitrate_data_0 + bitrate_data_1 + bitrate_data_2) / 3
avg_frame_rate = (frame_rate_data_0 + frame_rate_data_1 + frame_rate_data_2) / 3

# Print statements for comparison
print("=== Frame Information ===")
print("Number of total frames: {} vs {} vs {} | Average: {:.2f}".format(
    num_frames_total_data_0, num_frames_total_data_1, num_frames_total_data_2, avg_total_frames))
print("Number of rendered frames: {} vs {} vs {} | Average: {:.2f}".format(
    num_frames_rendered_data_0, num_frames_rendered_data_1, num_frames_rendered_data_2, avg_rendered_frames))
print("Number of dropped frames: {} vs {} vs {} | Average: {:.2f}".format(
    num_frames_dropped_data_0, num_frames_dropped_data_1, num_frames_dropped_data_2, avg_dropped_frames))

print("\n=== Percentage of Rendered Frames ===")
print("Percentage of rendered frames: {:.2f}% vs {:.2f}% vs {:.2f}% | Average: {:.2f}%".format(
    percentage_of_rendered_frames_data_0, percentage_of_rendered_frames_data_1, percentage_of_rendered_frames_data_2, avg_percentage_rendered_frames))

print("\n=== Stalled Frames ===")
print("Number of stall events: {} vs {} vs {} | Average: {:.2f}".format(
    num_of_stall_events_data_0, num_of_stall_events_data_1, num_of_stall_events_data_2, avg_num_of_stall_events))
print("Total stall duration (ms): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    total_stall_duration_data_0, total_stall_duration_data_1, total_stall_duration_data_2, avg_total_stall_duration))

print("\n=== Latencies ===")
print("Average behind live (ms): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    avg_behindLive_data_0, avg_behindLive_data_1, avg_behindLive_data_2, avg_behindLive))
print("Max behind live (ms): {:.2f} vs {:.2f} vs {:.2f}".format(
    max_behindLive_data_0, max_behindLive_data_1, max_behindLive_data_2))
print("Min behind live (ms): {:.2f} vs {:.2f} vs {:.2f}".format(
    min_behindLive_data_0, min_behindLive_data_1, min_behindLive_data_2))

print("Average buffer (ms): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    avg_buffer_data_0, avg_buffer_data_1, avg_buffer_data_2, avg_buffer))
print("Max buffer (ms): {:.2f} vs {:.2f} vs {:.2f}".format(
    max_buffer_data_0, max_buffer_data_1, max_buffer_data_2))
print("Min buffer (ms): {:.2f} vs {:.2f} vs {:.2f}".format(
    min_buffer_data_0, min_buffer_data_1, min_buffer_data_2))

print("Average total time (ms): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    avg_total_time_data_0, avg_total_time_data_1, avg_total_time_data_2, avg_total_time))
print("Max total time (ms): {:.2f} vs {:.2f} vs {:.2f}".format(
    max_total_time_data_0, max_total_time_data_1, max_total_time_data_2))
print("Min total time (ms): {:.2f} vs {:.2f} vs {:.2f}".format(
    min_total_time_data_0, min_total_time_data_1, min_total_time_data_2))

print("25th Percentile total time (ms): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    total_time_percentiles_data_0[0.25], total_time_percentiles_data_1[0.25], total_time_percentiles_data_2[0.25], avg_25th_percentile))
print("50th Percentile (Median) total time (ms): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    total_time_percentiles_data_0[0.5], total_time_percentiles_data_1[0.5], total_time_percentiles_data_2[0.5], avg_50th_percentile))
print("75th Percentile total time (ms): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    total_time_percentiles_data_0[0.75], total_time_percentiles_data_1[0.75], total_time_percentiles_data_2[0.75], avg_75th_percentile))

print("Standard Deviation of total time (ms): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    total_time_std_dev_data_0, total_time_std_dev_data_1, total_time_std_dev_data_2, avg_total_time_std_dev))

print("\n=== Performance Metrics ===")
print("Received Bitrate (Mbps): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    bitrate_data_0, bitrate_data_1, bitrate_data_2, avg_bitrate))
print("Frames per second (FPS): {:.2f} vs {:.2f} vs {:.2f} | Average: {:.2f}".format(
    frame_rate_data_0, frame_rate_data_1, frame_rate_data_2, avg_frame_rate))
# Out:
# === Frame Information ===
# Number of total frames: 1760 vs 1818 vs 1762 | Average: 1780.00
# Number of rendered frames: 1736 vs 1805 vs 1724 | Average: 1755.00
# Number of dropped frames: 24 vs 13 vs 38 | Average: 25.00
#
# === Percentage of Rendered Frames ===
# Percentage of rendered frames: 98.64% vs 99.28% vs 97.84% | Average: 98.59%
#
# === Stalled Frames ===
# Number of stall events: 24 vs 12 vs 38 | Average: 24.67
# Total stall duration (ms): 5825.00 vs 4298.00 vs 5682.00 | Average: 5268.33
#
# === Latencies ===
# Average behind live (ms): 1425.09 vs 2074.29 vs 1242.99 | Average: 1580.79
# Max behind live (ms): 3727.00 vs 3322.00 vs 2722.00
# Min behind live (ms): 216.00 vs 1017.00 vs 84.00
# Average buffer (ms): 880.51 vs 1245.59 vs 722.97 | Average: 949.69
# Max buffer (ms): 2621.00 vs 2686.00 vs 2661.00
# Min buffer (ms): 14.00 vs 18.00 vs 16.00
# Average total time (ms): 2305.61 vs 3319.89 vs 1965.95 | Average: 2530.48
# Max total time (ms): 5297.00 vs 5308.00 vs 5307.00
# ...

# %%
# Determine the length of the shortest DataFrame
min_length = min(len(df_data_0), len(df_data_1), len(df_data_2))

# Trim all DataFrames to the length of the shortest DataFrame
df_data_0_trimmed = df_data_0.iloc[:min_length]
df_data_1_trimmed = df_data_1.iloc[:min_length]
df_data_2_trimmed = df_data_2.iloc[:min_length]

# Create a new DataFrame for the average values
df_data_avg = pd.DataFrame()
df_data_avg['second'] = df_data_0_trimmed['second']

# Calculate the average of the total latency
df_data_avg['behindLive'] = (
    df_data_0_trimmed['behindLive'] + 
    df_data_1_trimmed['behindLive'] + 
    df_data_2_trimmed['behindLive']
) / 3

df_data_avg['buffer'] = (
    df_data_0_trimmed['buffer'] + 
    df_data_1_trimmed['buffer'] + 
    df_data_2_trimmed['buffer']
) / 3

df_data_avg['totalLatency'] = (
    df_data_0_trimmed['totalLatency'] + 
    df_data_1_trimmed['totalLatency'] + 
    df_data_2_trimmed['totalLatency']
) / 3

# Create a dictionary with the additional average values
additional_avg_data = {
    'avg_total_frames': avg_total_frames,
    'avg_rendered_frames': avg_rendered_frames,
    'avg_skipped_frames': avg_dropped_frames,
    'avg_percentage_rendered_frames': avg_percentage_rendered_frames,
    'avg_num_of_stall_events': avg_num_of_stall_events,
    'avg_stall_duration': avg_total_stall_duration,
    'avg_behindLive': avg_behindLive,
    'avg_buffer': avg_buffer,
    'avg_total_time': avg_total_time,
    'avg_25th_percentile_total_time': avg_25th_percentile,
    'avg_50th_percentile_total_time': avg_50th_percentile,
    'avg_75th_percentile_total_time': avg_75th_percentile,
    'avg_std_dev_total_time': avg_total_time_std_dev,
    'avg_received_bitrate': avg_bitrate,
    'avg_fps': avg_frame_rate
}

# Convert the dictionary to a DataFrame and merge it with df_data_avg
df_additional_avg = pd.DataFrame([additional_avg_data])
df_data_avg = df_data_avg.reset_index(drop=True)
df_data_avg = pd.concat([df_data_avg, df_additional_avg], axis=1)

# %%
# Function to sample and smooth the data
def sample_and_smooth(data, timestamp_col, value_col, sample_rate=1, window_size=30):
    # Sampling
    sampled_data = data.iloc[::sample_rate, :]
    
    # Smoothing using a rolling window
    smoothed_values = sampled_data[value_col].rolling(window=window_size).mean()
    
    return sampled_data[timestamp_col], smoothed_values

# Sampling rate and window size for smoothing
sample_rate = 30  # Take every 30th frame
window_size = 10  # Rolling window size for smoothing

# Plotting
plt.figure(figsize=(12, 8))

# Sample and smooth data for each scenario
timestamps_0, smoothed_0 = sample_and_smooth(df_data_0, 'second', 'totalLatency', sample_rate, window_size)
timestamps_1, smoothed_1 = sample_and_smooth(df_data_1, 'second', 'totalLatency', sample_rate, window_size)
timestamps_2, smoothed_2 = sample_and_smooth(df_data_2, 'second', 'totalLatency', sample_rate, window_size)
# timestamps_avg_behind_live, smoothed_avg_behind_live = sample_and_smooth(df_data_avg, 'second', 'behindLive', sample_rate, window_size)
# timestamps_avg_buffer, smoothed_avg_buffer = sample_and_smooth(df_data_avg, 'second', 'buffer', sample_rate, window_size)
timestamps_avg_total_latency, smoothed_avg_total_latency = sample_and_smooth(df_data_avg, 'second', 'totalLatency', sample_rate, window_size)

# Plotting the smoothed data
plt.plot(timestamps_0, smoothed_0, label='0')
plt.plot(timestamps_1, smoothed_1, label='1')
plt.plot(timestamps_2, smoothed_2, label='2')
plt.plot(timestamps_avg_total_latency, smoothed_avg_total_latency, label='Average')

# Adding labels, grid, and legend
plt.xlabel('Time (s)')
plt.ylabel('Latency (ms)')
plt.grid(True)
plt.legend()
plt.title('Latency Comparison')
plt.show()

# %%
json_data = df_data_avg.to_json(orient='records')

# Save the JSON data to a file
output_file_path = 'dash_frag100res1080fps30bit6gop2loss8delay0bw100 (avg).json'
with open(output_file_path, 'w') as json_file:
    json_file.write(json_data)

print(f'JSON file saved to {output_file_path}')
# Out:
# JSON file saved to dash_frag100res1080fps30bit6gop2loss8delay0bw100 (avg).json
